# %% [markdown]
# # 第6回　モデル評価とチューニング
# ***
# ## 目次
# 1. 交差検証とグリッドサーチ
# 2. 混同行列と評価指標
# 3. モデルの比較評価

# %%
# 今回使用するライブラリのインポート (はじめに実行してください！！！！！！！)
# データ加工・処理・分析ライブラリ
import pandas as pd

# データセット
from sklearn.datasets import load_breast_cancer

# 学習データの作成
from sklearn.model_selection import train_test_split

# 機械学習ライブラリ
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## 問題1
# ***
# 乳がんデータセットに対して，決定木を使ってグリッドサーチと5分割交差検証を行ってください．なお，決定木のハイパラメータに関しては，以下の条件に従ってください．
#
# - max_depth(木の深さ): 2, 3, 4, 5
# - min_samples_leaf(分岐に含まれるべき最小サンプル数): 2, 3, 4, 5

# %%
# データ読み込み
cancer = load_breast_cancer()
x_train, x_test, y_train, y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=0)
print("\nTraining Data")
print("\t説明変数 X のサイズ :", len(x_train))
print("\t目的変数 Y のサイズ :", len(y_train))
print("Testing Data")
print("\t説明変数 X のサイズ :", len(x_test))
print("\t目的変数 Y のサイズ :", len(y_test))

# 決定木クラスの初期化 (※ 引数は，「criterion='entropy'」と「random_state=0」)
# ここにあなたのコードを書いてください


# パラメータの準備
# ここにあなたのコードを書いてください


# GridSearchCVクラスの初期化と学習 (※ 分割数は，「cv = 5」)
# ここにあなたのコードを書いてください

# 結果の出力
# ここにあなたのコードを追加してください

# %% [markdown]
# ## 問題2
# ***
# 乳がんデータセットに対して，ロジスティック回帰モデルを構築し，混同行列を作ってください．また，テストデータにおける「正解率・適合率・再現率・F1スコア」の値をScikit-learnの関数を用いて取得してください．`sklearn.metrics`モジュールにおける，それぞれの関数の使用方法に関しては以下に示します．
#
# - 正解率：accuracy_score(y_test, y_pred)
# - 適合率：precision_score(y_test, y_pred)
# - 再現率：recall_score(y_test, y_pred)
# - F1スコア：f1_score(y_test, y_pred)

# %%
# データ読み込み
cancer = load_breast_cancer()
x_train, x_test, y_train, y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=0)
print("\nTraining Data")
print("\t説明変数 X のサイズ :", len(x_train))
print("\t目的変数 Y のサイズ :", len(y_train))
print("Testing Data")
print("\t説明変数 X のサイズ :", len(x_test))
print("\t目的変数 Y のサイズ :", len(y_test))

# ロジスティック回帰クラスの初期化と学習
# ここにあなたのコードを書いてください


# テストデータに対する予測
# ここにあなたのコードを書いてください．


# 結果の出力
# ここにあなたのコードを追加してください

# %% [markdown]
# ## 問題3
# ***
# 乳がんデータセットに対して，以下の条件で予測モデルを構築し，ホールドアウト法により，どのモデルが一番良いか確認してください．
#
# - 目的変数: cancer.target
# - 説明変数: cancer.data
# - 予測モデル: ロジスティック回帰，SVM，決定木，k-NN
# - 評価手法: ホールドアウト法

# %%
# データ読み込み
cancer = load_breast_cancer()
x_train, x_test, y_train, y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=0)
print("\nTraining Data")
print("\t説明変数 X のサイズ :", len(x_train))
print("\t目的変数 Y のサイズ :", len(y_train))
print("Testing Data")
print("\t説明変数 X のサイズ :", len(x_test))
print("\t目的変数 Y のサイズ :", len(y_test))

# モデルの設定
# ここにあなたのコードを書いてください


# 学習と評価値の計算
# ここにあなたのコードを書いてください


# 結果の出力
# ここにあなたのコードを書いてください
