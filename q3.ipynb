# %% [markdown]
# # 第3回　統計と単回帰分析
# ***
# 1. 記述統計量
# 2. 散布図と相関係数
# 3. 単回帰分析

# %%
import pandas as pd

DATA_BASE = "https://raw.githubusercontent.com/ShotaYmzk/AI-kadai/main/data"

def load_student_csv(filename: str) -> pd.DataFrame:
    return pd.read_csv(f"{DATA_BASE}/student/{filename}", sep=";")

# %% [markdown]
# ## 問題1
# ***
# ポルトガル語の成績データである`student-por.csv`を使って，生徒の成績に関する記述統計量を求めます．データはDataFrameオブジェクト`df_student_por`として読み込まれており，「一学期の成績`G1`，二学期の成績`G2`，三学期の成績`G3`」となっています．各学期の成績に対する「平均値・標準偏差・中央値」を求めて出力してください．
# - `G1`: 一学期の成績
# - `G2`: 二学期の成績
# - `G3`: 三学期の成績
# ***
#
# `student-por.csv` は GitHub 上の CSV を `read_csv` で読み込みます．
# データソース: [https://raw.githubusercontent.com/ShotaYmzk/AI-kadai/main/data/student/](https://raw.githubusercontent.com/ShotaYmzk/AI-kadai/main/data/student/)

# %%
# DataFrameオブジェクトとしてデータの読み込み
df_student_por = load_student_csv("student-por.csv")
df_student_por

# %%
# 各統計量の出力
# ここにあなたのコードを追加してください

# %% [markdown]
# ## 問題2
# ***
# ポルトガル語の成績データ`df_studnet_por`の各学期の成績`G1`，`G2`，`G3`に対して，各成績間の相関係数を求めてください．また，それらに関する**散布図**と**ヒストグラム**を，Seabornライブラリを用いて描画してください．

# %%
# データ間の相関係数
# ここにあなたのコードを追加してください

# %%
# G1, G2, G3に関する散布図とヒストグラム
# ここにあなたのコードを書いてください

# %% [markdown]
# ## 問題3
# ***
# ポルトガル語の成績データ`df_student_por`を用いて，三学期の成績`G3`を目的変数，二学期の成績`G2`を説明変数とした線形単回帰分析を行ってください．出力は「回帰係数・切片・決定係数」としてください．また，`G2`と`G3`間の散布図と，線形回帰式(予測モデル)を重ねて描画してください．

# %%
# 説明変数: 二学期の成績G2
# ここにあなたのコードを書いてください


# 目的変数: 三学期の成績G3
# ここにあなたのコードを書いてください


# 線形回帰linear_model.LinearRegressionのインスタンス生成
# ここにあなたのコードを書いてください


# 予測モデルの計算
# ここにあなたのコードを書いてください


# 出力
# ここにあなたのコードを追加してください

# %%
# 散布図の描画
# ここにあなたのコードを書いてください


# 重ねて線形回帰直線(予測モデル)の描画
# ここにあなたのコードを書いてください
