# %% [markdown]
# # 第1回　Pythonの基礎
# ***
# ## 目次
# 1. 自己紹介
# 2. キャンディー問題
# 3. 素数判定関数
# 4. 電卓クラス

# %% [markdown]
# ## 問題1
# ***
# **辞書型**変数を用いて，以下の項目についての自己紹介を出力してみましょう．
# - 名前
# - 学籍番号
# - 年齢
# - 出身地
#
# 次の例のように出力しましょう．
# ```
# Name : 芝浦太郎
# ID number : AF19000
# Age : 20
# Birthplace : Tokyo
# ```

# %%
# 辞書型変数を作成
# ここにあなたのコードを書いてください

# 自己紹介を出力
# ここにあなたのコードを書いてください

# %% [markdown]
# ## 問題2
# ***
# Aさん，Bさん，Cさんの3人はハロウィーンで飴を集めました．それぞれが集めた飴を持ち寄り，均等に分けることにしました．
# - 3人はそれぞれ何個ずつの飴を得ることができるでしょうか．
# - 分けきれなく余った雨は何個でしょうか．

# %%
# A, B, Cさんそれぞれが集めた飴の数
candy = {
    "a":121,
    "b":77,
    "c":109,
}

# 計算処理
# ここにあなたのコードを書いてください

# 出力
# ここにあなたのコードを追加してください

# %% [markdown]
# ## 問題3
# ***
# 2以上の自然数Nが与えられたとき，2からNまでの整数で素数のみを表示する関数`primality_test`を実装してください．
#
# 例えば，N=10のとき以下のような数値を出力しましょう．
#
# 2, 3, 5, 7

# %%
"""
@@@ ヒント @@@

ある自然数 N が素数かどうか判定するためには、2 から N までの数字で N が割り切れないことを確認します。
N が 2 から N までの数字で割り切れなければ、Nは素数です。

x から任意の数 y までの自然数を生成したい場合、range(x, y+1) という形で生成できます。
x から任意の数 y までの奇数を生成したい場合、x が奇数であれば、range(x, y+1, 2) という形で生成できます。

x から任意の数 y までの自然数を for でループさせる場合は for i in range(x, y+1): を使いましょう。(i の部分は任意です)

"""

# [2, N]での素数を出力する関数
def primality_test(n:int):
  # ここにあなたのコードを追加してください


# N=10のときの実行
primality_test(10)

# %% [markdown]
# ## 問題4
# ***
# 与えられた4つの数値に対して，「加算・減算・乗算・徐算」を実行するクラス`Calculator`を作成してください．
# - 4つの数値はインスタンス生成時に指定されます．
# - 加算:`add`，減算:`sub`，乗算:`multi`，徐算:`div`メソッドを呼び出すことで，それらの演算を実行します．

# %%
"""
@@@ ヒント @@@

コンストラクタの書き方は def __init__(self, その他の引数): という書き方になります。
コンストラクタの第1引数は self 固定です。
C++ でいうところの this ポインタの役割なので必須です。

メンバ変数の定義はコンストラクタ内で行います。
メンバ変数を呼び出すときは self を使います。
ex)
self.a = 10 ... メンバ変数 a に 10 を代入 (コンストラクタ内では代入宣言) する。

メンバメソッドも第1引数は self 固定です。
コンストラクタと同じです。

"""

# 電卓クラス
class Calculator:
  # ここにあなたのコードを追加してください


# 出力例
print('インスタンス1')
calc_1 = Calculator(64, 4, 4, 2)
print('加算:', calc_1.add())
print('減算:', calc_1.sub())
print('乗算:', calc_1.multi())
print('徐算:', calc_1.div())

print('インスタンス2')
calc_2 = Calculator(56, 7, 2, 4)
print('加算:', calc_2.add())
print('減算:', calc_2.sub())
print('乗算:', calc_2.multi())
print('徐算:', calc_2.div())
